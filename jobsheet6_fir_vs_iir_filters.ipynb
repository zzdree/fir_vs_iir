# %% [markdown]
# Nama : Andreas Restuawanta Christwara
#
# NIM : 5312422036
#
# Prodi : Teknik Komputer
#
# Matkul : Pengolahan Sinyal Digital

# %%
# %matplotlib notebook
from scipy.signal import freqz
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter, MultipleLocator

# %% [markdown]
# Kode tersebut merupakan kode Python yang bertujuan untuk melakukan analisis frekuensi dan menampilkan plot respon frekuensi menggunakan library SciPy dan Matplotlib.
#
# 1.	%matplotlib notebook: Baris ini digunakan dalam lingkungan Jupyter Notebook untuk menampilkan plot secara interaktif di dalam notebook.
# 2.	from scipy.signal import freqz: Baris ini mengimpor fungsi freqz dari modul signal dalam library SciPy. Fungsi freqz digunakan untuk menghitung respon frekuensi dari sistem linier.
# 3.	import numpy as np: Baris ini mengimpor library NumPy dengan alias np. NumPy digunakan untuk operasi numerik pada array dan matriks.
# 4.	import matplotlib.pyplot as plt: Baris ini mengimpor modul pyplot dari library Matplotlib dengan alias plt. Matplotlib digunakan untuk membuat plot dan visualisasi data.
# 5.	from matplotlib.ticker import FuncFormatter, MultipleLocator: Baris ini mengimpor kelas FuncFormatter dan MultipleLocator dari modul ticker dalam library Matplotlib. Keduanya digunakan untuk mengatur format dan posisi label pada sumbu plot.
#
# Kode ini merupakan persiapan untuk melakukan analisis frekuensi menggunakan library SciPy dan visualisasi plot respon frekuensi menggunakan Matplotlib. Dengan mengimpor modul-modul yang diperlukan, Anda dapat menggunakan fungsi-fungsi seperti freqz untuk menghitung respon frekuensi dan membuat plot dengan Matplotlib. Kode ini hanya merupakan langkah awal, dan Anda perlu menambahkan kode lain untuk melakukan analisis dan visualisasi yang sebenarnya.

# %%
A=np.array([1,-0.9])
B=np.array([1])
w, h = freqz(B, A, worN=512, whole=False)

# %% [markdown]
# Kode tersebut merupakan kelanjutan dari persiapan sebelumnya untuk melakukan analisis frekuensi menggunakan fungsi freqz dari library SciPy.
#
# 1.	A=np.array([1,-0.9]): Baris ini membuat array NumPy A yang mewakili koefisien polinomial penyebut dari sistem linier yang akan dianalisis. Dalam kasus ini, koefisien polinomial adalah 1 - 0.9z^-1.
# 2.	B=np.array([1]): Baris ini membuat array NumPy B yang mewakili koefisien polinomial pembilang dari sistem linier yang akan dianalisis. Dalam kasus ini, koefisien polinomial hanya memiliki satu nilai, yaitu 1.
# 3.	w, h = freqz(B, A, worN=512, whole=False): Baris ini memanggil fungsi freqz dari library SciPy untuk menghitung respon frekuensi dari sistem linier yang diwakili oleh koefisien polinomial B dan A. Argumen worN=512 menentukan jumlah titik frekuensi yang akan dihitung, sedangkan whole=False mengindikasikan bahwa hanya setengah dari rentang frekuensi akan dihitung (dari 0 hingga frekuensi Nyquist). Fungsi freqz mengembalikan dua array, yaitu w yang berisi nilai-nilai frekuensi angular dalam satuan radian/sampel, dan h yang berisi nilai-nilai respon frekuensi kompleks.
#
# Kode ini melakukan perhitungan respon frekuensi untuk sistem linier dengan koefisien polinomial penyebut 1 - 0.9z^-1 dan koefisien polinomial pembilang 1. Hasil perhitungan disimpan dalam variabel w (nilai-nilai frekuensi angular) dan h (nilai-nilai respon frekuensi kompleks). Untuk memvisualisasikan hasil perhitungan, Anda perlu menambahkan kode lain yang menggunakan library Matplotlib untuk membuat plot respon frekuensi.

# %%
fig = plt.figure()
plt.title('Digital filter frequency response')
plt.subplot(2,1,1)
plt.plot(w, 20 * np.log10(abs(h)), 'b')
plt.ylabel('Amplitude (dB)')
plt.xlabel('Normalized Frequency')
plt.grid()
ax = plt.gca()
ax.xaxis.set_major_formatter(FuncFormatter(
   lambda val,pos: '{:.0g}$\pi$'.format(val/np.pi) if val !=0 else '0'
))
ax.xaxis.set_major_locator(MultipleLocator(base=0.5))
plt.subplot(2,1,2)
angles = np.angle(h)
plt.plot(w, angles, 'g')
plt.ylabel('Angle (radians)')
plt.xlabel('Normalized Frequency')
ax = plt.gca()
ax.xaxis.set_major_formatter(FuncFormatter(
   lambda val,pos: '{:.0g}$\pi$'.format(val/np.pi) if val !=0 else '0'
))
ax.xaxis.set_major_locator(MultipleLocator(base=0.5))
plt.grid()
plt.tight_layout()
# Out:
# <div id='f9098a94-98cc-4e8b-b005-0ed9386ac9cc'></div>
# <ipython-input-21-8aeb8662ccef>:3: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(2,1,1)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Kode tersebut digunakan untuk memvisualisasikan respon frekuensi dari sistem linier yang telah dihitung sebelumnya menggunakan fungsi freqz dari SciPy. Kode ini menggunakan library Matplotlib untuk membuat plot dengan dua subplot, yaitu satu untuk menampilkan amplitudo respon frekuensi dalam skala desibel (dB) dan satu lagi untuk menampilkan sudut fase respon frekuensi dalam radian.
#
# 1.	fig = plt.figure(): Baris ini membuat objek figure baru untuk menampilkan plot.
# 2.	plt.title('Digital filter frequency response'): Baris ini menambahkan judul untuk plot.
# 3.	plt.subplot(2,1,1): Baris ini membuat subplot pertama dengan ukuran 2 baris dan 1 kolom, dan memilih subplot pertama untuk diisi.
# 4.	plt.plot(w, 20 * np.log10(abs(h)), 'b'): Baris ini membuat plot amplitudo respon frekuensi dalam skala desibel (dB) dengan sumbu x sebagai frekuensi angular (w) dan sumbu y sebagai 20 kali logaritma basis 10 dari nilai absolut respon frekuensi (h). Warna garis plot adalah biru ('b').
# 5.	plt.ylabel('Amplitude (dB)'), plt.xlabel('Normalized Frequency'), plt.grid(): Baris-baris ini menambahkan label sumbu y, label sumbu x, dan grid pada subplot.
# 6.	ax = plt.gca(): Baris ini mendapatkan objek sumbu x saat ini.
# 7.	ax.xaxis.set_major_formatter(FuncFormatter(...)): Baris ini mengatur format label sumbu x menggunakan fungsi FuncFormatter dari Matplotlib. Label akan ditampilkan dalam bentuk n*pi jika nilai tidak sama dengan 0, atau '0' jika nilainya 0.
# 8.	ax.xaxis.set_major_locator(MultipleLocator(base=0.5)): Baris ini mengatur posisi label sumbu x menggunakan MultipleLocator dari Matplotlib. Label akan ditampilkan setiap kelipatan 0.5 dari nilai maksimum sumbu x.
# 9.	plt.subplot(2,1,2): Baris ini membuat subplot kedua dengan ukuran 2 baris dan 1 kolom, dan memilih subplot kedua untuk diisi.
# 10.	angles = np.angle(h): Baris ini mengambil sudut fase dari respon frekuensi kompleks h menggunakan fungsi np.angle dari NumPy.
# 11.	plt.plot(w, angles, 'g'): Baris ini membuat plot sudut fase respon frekuensi dengan sumbu x sebagai frekuensi angular (w) dan sumbu y sebagai sudut fase (angles). Warna garis plot adalah hijau ('g').
# 12.	plt.ylabel('Angle (radians)'), plt.xlabel('Normalized Frequency'), plt.grid(): Baris-baris ini menambahkan label sumbu y, label sumbu x, dan grid pada subplot.
# 13.	ax = plt.gca(): Baris ini mendapatkan objek sumbu x saat ini.
# 14.	ax.xaxis.set_major_formatter(FuncFormatter(...)): Baris ini mengatur format label sumbu x menggunakan fungsi FuncFormatter dari Matplotlib, sama seperti pada subplot pertama.
# 15.	ax.xaxis.set_major_locator(MultipleLocator(base=0.5)): Baris ini mengatur posisi label sumbu x menggunakan MultipleLocator dari Matplotlib, sama seperti pada subplot pertama.
# 16.	plt.tight_layout(): Baris ini menyesuaikan tata letak subplot agar tidak terpotong.
#
# Kode ini membuat plot dengan dua subplot untuk memvisualisasikan respon frekuensi dari sistem linier yang telah dihitung sebelumnya. Subplot pertama menampilkan amplitudo respon frekuensi dalam skala desibel (dB), sedangkan subplot kedua menampilkan sudut fase respon frekuensi dalam radian. Kode ini juga mengatur format dan posisi label sumbu x menggunakan FuncFormatter dan MultipleLocator dari Matplotlib agar label ditampilkan dalam bentuk kelipatan pi. Hasil akhir adalah visualisasi respon frekuensi yang informatif dengan dua subplot dalam satu figure.

# %%
def zplane(B,A):
    # Plot Poles and Zeros
    from  matplotlib import patches
    plt.figure(figsize=(6,4))
    ax = plt.subplot(111)
    r = 1.5; plt.axis('scaled'); plt.axis([-r, r, -r, r])
    #ticks = [-1, 1]; plt.xticks(ticks); plt.yticks(ticks)
    # Unit Circle
    uc = patches.Circle((0,0), radius=1, fill=False, color='black', ls='dashed')
    ax.add_patch(uc)
    ax.spines['left'].set_position('center')
    ax.spines['bottom'].set_position('center')
    ax.spines['right'].set_visible(False)
    ax.spines['top'].set_visible(False)
    plt.xlabel('Re', horizontalalignment='right', x=1.0)
    plt.ylabel('Im',  y=1.0)
    plt.title('Complex z-Plane', loc='right')
    plt.grid()
    plt.plot(np.real(A),np.imag(A),'rx')
    plt.plot(np.real(B),np.imag(B),'bo')

# %% [markdown]
# Kode tersebut adalah sebuah fungsi Python bernama zplane yang digunakan untuk memplot Pole dan Zero dari suatu sistem linier pada bidang kompleks z.
#
# 1.	def zplane(B, A): Baris ini mendeklarasikan sebuah fungsi bernama zplane yang menerima dua argumen B dan A. B adalah array yang berisi koefisien pembilang, dan A adalah array yang berisi koefisien penyebut dari sistem linier.
# 2.	from matplotlib import patches Baris ini mengimpor modul patches dari library Matplotlib yang digunakan untuk membuat objek-objek geometris seperti lingkaran pada plot.
# 3.	plt.figure(figsize=(6, 4)) Baris ini membuat sebuah figure baru dengan ukuran 6 x 4 inci.
# 4.	ax = plt.subplot(111) Baris ini membuat sebuah sumbu (axes) tunggal pada figure.
# 5.	r = 1.5; plt.axis('scaled'); plt.axis([-r, r, -r, r]) Baris-baris ini menyesuaikan batas sumbu x dan y agar lingkaran satuan dapat ditampilkan dengan baik.
# 6.	uc = patches.Circle((0, 0), radius=1, fill=False, color='black', ls='dashed') Baris ini membuat objek lingkaran dengan pusat di (0, 0) dan jari-jari 1, dengan garis putus-putus berwarna hitam.
# 7.	ax.add_patch(uc) Baris ini menambahkan lingkaran yang telah dibuat pada sumbu (axes).
# 8.	ax.spines['left'].set_position('center'), ax.spines['bottom'].set_position('center'), ax.spines['right'].set_visible(False), ax.spines['top'].set_visible(False) Baris-baris ini menyesuaikan tampilan sumbu agar lebih rapi dan hanya menampilkan sumbu x dan y.
# 9.	plt.xlabel('Re', horizontalalignment='right', x=1.0), plt.ylabel('Im', y=1.0), plt.title('Complex z-Plane', loc='right') Baris-baris ini menambahkan label sumbu x, sumbu y, dan judul plot.
# 10.	plt.grid() Baris ini menambahkan grid pada plot.
# 11.	plt.plot(np.real(A), np.imag(A), 'rx') Baris ini memplot Pole dari sistem linier yang diwakili oleh koefisien penyebut A dengan tanda silang berwarna merah.
# 12.	plt.plot(np.real(B), np.imag(B), 'bo') Baris ini memplot Zero dari sistem linier yang diwakili oleh koefisien pembilang B dengan tanda lingkaran berwarna biru.
#
# Fungsi zplane digunakan untuk memvisualisasikan Pole dan Zero dari suatu sistem linier pada bidang kompleks z. Fungsi ini menerima dua argumen, yaitu B dan A, yang mewakili koefisien pembilang dan penyebut dari sistem linier. Fungsi ini membuat sebuah plot dengan lingkaran satuan, sumbu x dan y, grid, dan memplot Pole dan Zero pada bidang kompleks z menggunakan tanda silang dan lingkaran dengan warna yang berbeda. Hasil akhir dari fungsi ini adalah sebuah visualisasi yang membantu dalam menganalisis sifat dan stabilitas dari sistem linier tersebut.

# %%
zplane(np.roots(B),np.roots(A))
# Out:
# <div id='4db90a79-9ba1-417f-9458-626b7e2cf721'></div>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ode zplane(np.roots(B), np.roots(A)) memanggil fungsi zplane yang telah dijelaskan sebelumnya dengan argumen np.roots(B) dan np.roots(A).
#
# 1.	np.roots(B): Baris ini menggunakan fungsi np.roots dari library NumPy untuk mencari akar-akar dari polinomial yang diwakili oleh koefisien B. Akar-akar ini merupakan nilai-nilai Zero dari sistem linier.
# 2.	np.roots(A): Baris ini juga menggunakan fungsi np.roots dari NumPy untuk mencari akar-akar dari polinomial yang diwakili oleh koefisien A. Akar-akar ini merupakan nilai-nilai Pole dari sistem linier.
# 3.	zplane(np.roots(B), np.roots(A)): Baris ini memanggil fungsi zplane dengan melewatkan akar-akar dari koefisien B dan A sebagai argumen. Akar-akar ini kemudian akan diplot pada bidang kompleks z sebagai Zero (lingkaran biru) dan Pole (silang merah).a
#
# Kode zplane(np.roots(B), np.roots(A)) memanggil fungsi zplane dengan melewatkan akar-akar dari koefisien polinomial pembilang B (yang mewakili Zero) dan koefisien polinomial penyebut A (yang mewakili Pole) sebagai argumen. Hasil dari kode ini adalah sebuah plot pada bidang kompleks z yang menampilkan Pole (silang merah) dan Zero (lingkaran biru) dari sistem linier yang dianalisis. Plot ini dapat digunakan untuk menganalisis sifat dan stabilitas sistem linier berdasarkan letak Pole dan Zero pada bidang kompleks z.

# %%
import scipy.signal
import matplotlib.pyplot as plt
#Start with a unit pulse as input x:
x=np.zeros(30)
x[0] = 1
#B and A are given as before:
A=[1,-0.9];
B=[1];
#Now calculate the impulse response:
y=scipy.signal.lfilter(B,A,x);
plt.figure()
plt.stem(y, use_line_collection=True)
plt.xlabel('Sample')
plt.ylabel('Value')
plt.grid()
# Out:
# <div id='91253f98-0a09-4fac-8db8-948373e7da85'></div>
# <ipython-input-24-b9fc3f4c416d>:12: MatplotlibDeprecationWarning: The 'use_line_collection' parameter of stem() was deprecated in Matplotlib 3.6 and will be removed two minor releases later. If any parameter follows 'use_line_collection', they should be passed as keyword, not positionally.
#   plt.stem(y, use_line_collection=True)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Kode tersebut digunakan untuk menghitung dan memvisualisasikan respon impuls dari suatu sistem linier menggunakan library SciPy dan Matplotlib dalam Python.
#
# 1.	import scipy.signal: Baris ini mengimpor modul signal dari library SciPy yang berisi berbagai fungsi untuk memproses sinyal.
# 2.	import matplotlib.pyplot as plt: Baris ini mengimpor modul pyplot dari library Matplotlib yang digunakan untuk memvisualisasikan data dalam bentuk plot.
# 3.	x = np.zeros(30) dan x[0] = 1: Baris-baris ini membuat array x dengan panjang 30 yang berisi nilai 0, kecuali pada indeks ke-0 yang bernilai 1. Array ini mewakili input impuls unit.
# 4.	A = [1, -0.9] dan B = [1]: Baris-baris ini mendefinisikan koefisien polinomial penyebut A dan koefisien polinomial pembilang B dari sistem linier yang akan dianalisis.
# 5.	y = scipy.signal.lfilter(B, A, x): Baris ini menggunakan fungsi lfilter dari modul scipy.signal untuk menghitung respon impuls y dari sistem linier dengan koefisien B dan A serta input x.
# 6.	plt.figure(): Baris ini membuat figure baru untuk memplot data.
# 7.	plt.stem(y, use_line_collection=True): Baris ini membuat plot stem (garis vertikal dengan titik pada akhir) untuk menampilkan nilai-nilai respon impuls y pada sumbu y.
# 8.	plt.xlabel('Sample') dan plt.ylabel('Value'): Baris-baris ini menambahkan label untuk sumbu x dan sumbu y pada plot.
# 9.	plt.grid(): Baris ini menambahkan grid pada plot untuk memudahkan pembacaan nilai-nilai pada sumbu.
#
# Kode ini digunakan untuk menghitung dan memvisualisasikan respon impuls dari suatu sistem linier dengan koefisien polinomial penyebut A = [1, -0.9] dan koefisien polinomial pembilang B = [1]. Input yang digunakan adalah impuls unit dengan panjang 30. Respon impuls dihitung menggunakan fungsi lfilter dari SciPy, dan hasilnya divisualisasikan dalam bentuk plot stem menggunakan Matplotlib. Dengan melihat respon impuls, kita dapat menganalisis sifat dan karakteristik dari sistem linier tersebut.
